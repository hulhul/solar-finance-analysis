# %%
import pandas as pd
import numpy as np

# %%
sfd = pd.read_csv("Solar Finance Project - Data.csv",thousands=',')

# %%
sfd
# Out:
#                  City  Break even   Latitude   Longitude  Zipcode  \
# 0       San Diego, CA           4  32.715738 -117.161084    92154
# 1        San Jose, CA           4  37.338740 -121.885253    95123
# 2   San Fransisco, CA           5  37.774929 -122.419415    94112
# 3        Honolulu, HI           5  21.309884 -157.858140    96818
# 4    Philadelphia, PA           9  39.952584  -75.165222    19120
# 5           Miami, FL          10  25.761680  -80.191790    33125
# 6       Baltimore, MD          10  39.290385  -76.612189    21215
# 7          Denver, CO          11  39.739236 -104.990251    80219
# 8      Washington, DC          12  38.907192  -77.036871    20011
# 9          Boston, MA          12  42.360082  -71.058880     2124
# 10      Nashville, TN          13  36.162664  -86.781602    37211
# 11  New York City, NY          14  40.712775  -74.005973    11368
# 12         Austin, TX          14  30.267153  -97.743061    78745
# ...

# %%
sfdWeather = pd.read_csv("SolarFinanceProjectWeatherData.csv")

# %%
sfdWeather.head(10)
# Out:
#            name  tempmax  tempmin  temp  precip  precipcover  windspeedmean  \
# 0  Honolulu, HI     24.8     19.5  22.2  80.461        75.00           14.0
# 1  Honolulu, HI     22.2     19.3  20.6  37.753        54.17            6.2
# 2  Honolulu, HI     24.2     19.1  21.4  11.910        33.33            6.1
# 3  Honolulu, HI     25.3     19.5  22.5   6.101        45.83            9.0
# 4  Honolulu, HI     25.9     20.3  23.0   3.980         8.33            7.0
# 5  Honolulu, HI     26.1     19.2  22.8   1.716        12.50            8.8
# 6  Honolulu, HI     26.9     19.3  22.8   0.000         0.00            8.7
# 7  Honolulu, HI     26.4     17.8  22.3   0.000         0.00            8.6
# 8  Honolulu, HI     25.8     18.8  22.7   0.000         0.00            7.2
# 9  Honolulu, HI     26.4     18.9  22.8   0.000         0.00            8.3
#
#    sealevelpressure  cloudcover  visibility  solarradiation  solarenergy  \
# ...

# %%
sfdWeatherRedone = sfdWeather.groupby('name', as_index=False).mean()
sfdWeatherRedone
# Out:
#                  name    tempmax    tempmin       temp    precip  precipcover  \
# 0         Atlanta, GA  22.699452  12.323562  17.207123  3.049789     8.755671
# 1          Austin, TX  27.602466  15.228219  21.055068  1.698274     4.680466
# 2       Baltimore, MD  18.995068   9.303014  14.091781  2.522153     9.897370
# 3          Boston, MA  16.132055   7.958904  11.932055  2.154011    10.194110
# 4         Chicago, IL  15.805205   7.375342  11.548493  2.064959     9.155260
# 5          Denver, CO  17.903288   3.670959  10.426301  1.028836     5.730603
# 6        Honolulu, HI  28.840274  22.404932  25.365753  0.857353     5.125753
# 7           Miami, FL  29.189589  22.523836  25.594795  4.096381    10.639370
# 8     Minneapolis, MN  12.453973   3.066301   7.730959  1.426252     8.276329
# 9       Nashville, TN  21.878082  10.544384  16.060274  2.347981     8.607233
# 10    New Orleans, LA  25.917808  18.669589  22.085479  1.358529     7.500000
# ...

# %%
sfd = sfd.sort_values('City')
sfd
# Out:
#                  City  Break even   Latitude   Longitude  Zipcode  \
# 18        Atlanta, GA          18  33.748752  -84.387685    30318
# 12         Austin, TX          14  30.267153  -97.743061    78745
# 6       Baltimore, MD          10  39.290385  -76.612189    21215
# 9          Boston, MA          12  42.360082  -71.058880     2124
# 13        Chicago, IL          15  41.878114  -87.629798    60629
# 7          Denver, CO          11  39.739236 -104.990251    80219
# 3        Honolulu, HI           5  21.309884 -157.858140    96818
# 5           Miami, FL          10  25.761680  -80.191790    33125
# 15    Minneapolis, MN          15  44.977753  -93.265011    55407
# 10      Nashville, TN          13  36.162664  -86.781602    37211
# 19    New Orleans, LA          19  29.951066  -90.071532    70119
# 11  New York City, NY          14  40.712775  -74.005973    11368
# 4    Philadelphia, PA           9  39.952584  -75.165222    19120
# ...

# %%
sfdUpdated = sfd.set_index("City").join(sfdWeatherRedone.set_index("name"))
sfdUpdated
# Out:
#                    Break even   Latitude   Longitude  Zipcode  \
# City
# Atlanta, GA                18  33.748752  -84.387685    30318
# Austin, TX                 14  30.267153  -97.743061    78745
# Baltimore, MD              10  39.290385  -76.612189    21215
# Boston, MA                 12  42.360082  -71.058880     2124
# Chicago, IL                15  41.878114  -87.629798    60629
# Denver, CO                 11  39.739236 -104.990251    80219
# Honolulu, HI                5  21.309884 -157.858140    96818
# Miami, FL                  10  25.761680  -80.191790    33125
# Minneapolis, MN            15  44.977753  -93.265011    55407
# Nashville, TN              13  36.162664  -86.781602    37211
# New Orleans, LA            19  29.951066  -90.071532    70119
# New York City, NY          14  40.712775  -74.005973    11368
# Philadelphia, PA            9  39.952584  -75.165222    19120
# Portland, OR               15  45.515232 -122.678385    97206
# ...

# %%
sfdUpdatedNew = sfdUpdated.drop(columns=["NO2      AM (ppb)", "NO2          1-hr (ppb)", "SO2         1-hr (ppb)"])

# %%
sfdUpdatedNew.to_csv("SOLARFINANCEFINAL.csv")
